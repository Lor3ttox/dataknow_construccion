# %% [markdown]
# ## Parametros análisis exploratorio y modelacion para equipo de Construccion (Dataknow)
# ---

# %%
# 1 Carga de Bibliotecas para las rutas
import os
import sys

# %%
# Variables de ambiente (Blob Storage)
path_dlk = os.environ.get("abfss://rootadb@adbjuandataknow01.dfs.core.windows.net/construccion")

# Directorio de procesos
directorio_proceso = {"workspace": "/Workspace/Users/juanguerraosorio1984@gmail.com/dataknow_construccion"}

# Volumen del proceso
volumen_proceso = {"volumen": "/Volumes/dataknow_dll/construccion/construccion_archivos/"}

# Tablas a crear (actualizadas mediante el proceso)
table_names = [
    "bronze_construccion_completo",
    "bronze_X",
    "bronze_Y",
    "bronze_Z"
]
